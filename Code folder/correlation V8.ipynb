# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

merged_dataset = pd.read_csv("../data/pop_gni_merged.csv", index_col='country')
merged_dataset.head()
# Out:
#                       1800_pop  1800_gni  1801_pop  1801_gni  1802_pop  \
# country
# Afghanistan            3280000       207   3280000       207   3280000
# Angola                 1570000       517   1570000       519   1570000
# Albania                 400000       207    402000       207    404000
# United Arab Emirates     40200       738     40200       740     40200
# Argentina               534000       794    520000       797    506000
#
#                       1802_gni  1803_pop  1803_gni  1804_pop  1804_gni  ...  \
# country                                                                 ...
# Afghanistan                207   3280000       207   3280000       207  ...
# Angola                     522   1570000       524   1570000       525  ...
# Albania                    207    405000       207    407000       207  ...
# United Arab Emirates       743     40200       746     40200       749  ...
# ...

# %%
years = list(range(1800, 2051))
correlations = []

for year in years:
    pop_column = f"{year}_pop"
    gni_column = f"{year}_gni"
    correlation = merged_dataset[pop_column].corr(merged_dataset[gni_column])
    correlations.append(correlation)

# %%
plt.figure(figsize=(12, 6))
plt.plot(years, correlations, marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Correlation')
plt.title('Correlation between Population and GNI over the years')
plt.grid(True)
plt.tight_layout()
plt.show()
